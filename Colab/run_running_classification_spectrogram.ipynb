# %%
import os, os.path, datetime
import keras
from google.colab import drive 
drive.mount('/content/drive') 

# import PredictPower_functions
# %cd /content/drive/My\ Drive/Running Plantiga Project/Code
import script_running_classification_spectrogram_v2 as script
#import PredictPower_functions as ppf
#import openloop_algorithms as oa


#check if GPU is available
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('GPU device not found')
print('Found GPU at: {}'.format(device_name))


# %cd /content/drive/My\ Drive/Running Plantiga Project
dir_root = os.getcwd() + '/'

"""some variables"""

epochs = 1000
subjects = [34,35,36,37,38,40,41,42,43,45,46,48,49,52,53,54,55,58,59,60,61,62,63,66,67,68,69,70,72,73,74,77,79,80,82,84,85,87,88,89,90,91,92,93,94,95,96,98,99,100,101,102,104,105,106,107,108,110,111,112,113,114,115,116,118,119,120,122,123,125,126,127,128,130,131,132,133,135,138,139,140,142,143,146,147,150,151,154,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,173,174,176,177,179,180,182,184,185,186,188]
val_split = 0.2
batch_size = 32
model_to_use = 'lstm_model_class' # resnet50_class_more_conv_layers, or resnet50_class or # lstm_model_class
weights_to_use = "imagenet" #"imagenet"
dropout = 0
early_stopping_patience = 10
early_stopping_min_delta = 0
input_my_model = keras.Input(shape = (2000,1)) #keras.Input(shape = (126,40,12,1))  #keras.Input(shape = (10000,12)) # input for first layer
input_resnet = keras.Input(shape=(126,40,3)) # input after my own layers into the resnet
resnet_trainable = True
data_name = '2k_no_spectrogram'
which_spectrograms = data_name + '/Treadmill/'
model_name = data_name + 'unfrozen_nodrop'
#model_name = data_name + '_lstm'
classification = 1 # 0 if continuous
n_bins = 3
flag_shuffle_files = 0
flag_subject_id_classification = 0
flag_speed_classification = 1
test_speed = 2
layers_nodes = [16]
learning_rate = 2e-2


evaluated_train_loss, evaluated_val_loss = \
        script.script_running_classification_spectrogram_v2(subjects, dir_root, model_name,  weights_to_use, 
                                                 val_split, epochs, batch_size, dropout,
                                                 early_stopping_patience, early_stopping_min_delta,
                                                 input_my_model, input_resnet, which_spectrograms,
                                                 resnet_trainable, n_bins, classification,flag_shuffle_files,
                                                 model_to_use, layers_nodes, flag_speed_classification, test_speed,
                                                 learning_rate,flag_speed_classification)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Running Plantiga Project/Code
# Found GPU at: /device:GPU:0
# /content/drive/My Drive/Running Plantiga Project
# Train: 230
# Validation: 115
# model checkpoint included
# early stopping included
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_4 (LSTM)               (None, 16)                1152
#
#  dense_4 (Dense)             (None, 3)                 51
#
# ...
# Total params: 1,203
# Trainable params: 1,203
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# ...
